# %%
import import_ipynb
import data_extraction
# Out:
# importing Jupyter notebook from data_extraction.ipynb
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5782 entries, 2022-10-21 to 1999-11-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    5782 non-null   float64
#  1   high    5782 non-null   float64
#  2   low     5782 non-null   float64
#  3   close   5782 non-null   float64
#  4   volume  5782 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 271.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5782 entries, 2022-10-21 to 1999-11-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    5782 non-null   float64
#  1   high    5782 non-null   float64
#  2   low     5782 non-null   float64
#  3   close   5782 non-null   float64
#  4   volume  5782 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 271.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4631 entries, 2022-10-21 to 2004-06-02
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    4631 non-null   float64
#  1   high    4631 non-null   float64
#  2   low     4631 non-null   float64
#  3   close   4631 non-null   float64
#  4   volume  4631 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 217.1 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2019-01-02 to 2021-01-06
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       508 non-null    float64
#  1   VZ      508 non-null    float64
# dtypes: float64(2)
# memory usage: 11.9 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2019-01-02 to 2021-01-06
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       508 non-null    float64
#  1   VZ      508 non-null    float64
#  2   SP&500  508 non-null    float64
# dtypes: float64(3)
# memory usage: 15.9 KB
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 508 entries, 2019-01-02 to 2021-01-06
# Series name: T
# Non-Null Count  Dtype
# --------------  -----
# 508 non-null    float64
# dtypes: float64(1)
# memory usage: 7.9 KB
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 526 entries, 2019-01-02 to 2021-01-06
# Freq: B
# Series name: T
# Non-Null Count  Dtype
# --------------  -----
# 526 non-null    float64
# dtypes: float64(1)
# memory usage: 8.2 KB
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 508 entries, 2019-01-02 to 2021-01-06
# Series name: VZ
# Non-Null Count  Dtype
# --------------  -----
# 508 non-null    float64
# dtypes: float64(1)
# memory usage: 7.9 KB
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 526 entries, 2019-01-02 to 2021-01-06
# Freq: B
# Series name: VZ
# Non-Null Count  Dtype
# --------------  -----
# 526 non-null    float64
# dtypes: float64(1)
# memory usage: 8.2 KB

# %%
import matplotlib.pyplot as plt

# %%
ds = data_extraction.dataset

# %%
ds.head()
# Out:
#                 T     VZ  SP&500
# timestamp
# 2019-01-02  29.54  56.02   29.86
# 2019-01-03  29.58  56.22   29.02
# 2019-01-04  30.34  56.36   29.90
# 2019-01-07  30.89  56.72   30.79
# 2019-01-08  31.28  58.38   31.59

# %%
correlation_ds = ds["T"].corr(ds["VZ"])

# %%
print(correlation_ds)
# Out:
# 0.40016069342885296

# %%
plt.scatter(ds["T"], ds["VZ"])
plt.show()

# %%
changes = ds.pct_change()

# %%
print(changes["T"].corr(changes["VZ"]))
# Out:
# 0.7101822182602753

# %%
plt.scatter(changes["T"], changes["VZ"])
plt.show()
